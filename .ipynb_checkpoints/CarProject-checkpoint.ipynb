# %% [markdown]
# # Predicting the Price of Used Cars in Cebu using K-Nearest Neighbor and Multiple Regression Algorithm
#
# *•Arnado, Russ Azzi • Degamo, Ma. Lezly Grace • Mayormita, Riza Marie • Perez, Rodel • Tabañag, John Kaizer*
#
# ### Overview of the Study
# ***
#
# Cebu with it's population of 7,396,898, is one of the most riches province in the philippines with its annual GDP of 1,156,592 pesos. With its booming population and busy people, the demand for cars is increasing rapidly. According to Land Transportation Office Region 7, The number of newly registered vehicles in Cebu will increase year and Major cities in Cebu along may  800,000 registered vehicles by the end of 2019.
#
# The purchasing behavior of customers in the secondhand car market has been affected by the growing popularity of online classified advertisements and auto portals in the Philippines. The digital era’s technological advancements gave birth to various online platforms in which potential customers can explore in their journey of finding a car that would best suit their preferences. Various multi-brand dealers are strategically partnering with online classified advertisements and auto portals to make the car purchasing journey of potential buyers to be more convenient, accessible, and transparent.
#
# Due to the Tax Reform for Acceleration and Inclusion (TRAIN) Act in the Philippines, new vehicles have become more expensive which results to individuals resorting to certified and non-certified secondhand vehicles. The increase in demand on public transport and ride-sharing services to relieve traffic congestions will also expand the sales of used cars in the Philippines.
#
# Buying secondhand cars may have its advantages (e.g., cheaper) but it also has its risks such determining the reliability of the seller and whether if a used car is overpriced or not.
#
# To help alleviate the worries of potential used car buyers in their purchasing journey, we will now try to develop a model that would predict the price of secondhand cars and identify which specific features/variables greatly affect it.
#
# **Buying used cars has many advantages:**
#
# - More savings
# - Cheaper insurance cost
# - Slower depreciation
# - Extended warranty
# - Good for the environment
# - But there are also risks:
#
# - Unknown reliability or treatment
# - More frequent maintenance
# - Hard to find an exact match of what you want
# - Untouched warranty
# - Lemon Car / Overpriced Ca
#
# ### Variables Used
# ***
# - **ID** - Default primary key of the car records.
# - **Title** - The title or the name of cars displayed in the scraped website.
# - **Price** - The second hand price of the car.
# - **Brand** - The brand name of the car.
# - **Model** - The model name of the car.
# - **Year of Manufacture** - Car year of manufactured.
# - **Used** - A binary attribute that indicates wheather the item is second hand or not.
# - **Transmission** - Can be manual or automatic transmission.
# - **Color Family** - Car colors classified into color family.
# - **Mileage (in km)** - the total number of miles that the vehicle have travelled at the time it was purchased.
# - **Body Type** - Car style or type.
# - **Version** - Car's version number.
# - **Description** - Cars description in the website listing.
# - **Poster** -The one who post/sell the car in the website.
# - **Poster Type** - The type of entity/seller who post the item in the website.
# - **Fuel Type** - Car's fuel type
# - **Location.2** - Poster/Seller's location
# - **Date Posted** - Date of when the item is posted
# - **name** - Name of the car
# - **retail** - Original Retail price of the car in the market.
# - **Post Age** - The age from when it is posted by the poster/seller in the website.
#
#
#
#
#
# ### Population, Data Collection & Sampling
# ***
# The 20,088 data used for this project are car listings scraped from Carmudi and Philkotse websites. While, the retail price of the cars are scraped from Priceprice Auto and AutoSearch Manila.

# %% [markdown]
# ## Importing the necessary Libraries
# ***
# The first thing we need to do is import the libraries that will be using for this study. To visualize our data, we will be using `matplotlib` and `seaborn` to create heatmaps and a scatter matrix. To build our model, we will be using the `sklearn` library, and the evaluation will be taking place with the `statsmodels` library.

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from datetime import date
from dateutil.parser import parse
import numpy as np
from sklearn import preprocessing
from sklearn import tree, metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
#import graphviz
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset into Pandas
# ***
# After we've loaded our libraries, we can begin the process of importing and exploring our data. The dataset contains 20 explanatory variables and 1 dependent variable. After we've loaded the data into the data frame, we will need to filter our data and clean further to provide good insights.

# %%
cars = pd.read_csv("dataset/080119_pk and carmudi_complete.csv")
cars.head()
# Out:
#           ID                                              Title   Price  \
# 0  CAR006117  White Hyundai Grand Starex 2010 for sale in Ma...  665000
# 1  CAR006652    Selling Red Mitsubishi Mirage G4 2018 in Cainta  528000
# 2  CAR013853  Sell Silver 2011 Toyota Innova in General Sali...  595000
# 3  CAR013855  Red Toyota Innova 2012 Manual Gasoline for sal...  495000
# 4  CAR014563                     1989 Mercedes-Benz 260E 2.6 AT  255000
#
#            Brand        Model  Year of Manufacture Used Transmission  \
# 0        Hyundai  GrandStarex                 2010  Yes       Manual
# 1     Mitsubishi     MirageG4                 2018  Yes    Automatic
# 2         Toyota       Innova                 2011  Yes       Manual
# 3         Toyota       Innova                 2012  Yes       Manual
# 4  Mercedes-Benz         260E                 1989  Yes    Automatic
#
#   Color Family  Mileage (in km)  ... Version  \
# 0        White              1.0  ...     NaN
# ...

# %% [markdown]
# ## Data Cleaning
# ***
# ### Selecting Data that comes only from Cebu
# In order to select data that comes only from Cebu, We will need to count all the values inside our `location.2` variables.

# %%
pd.set_option('display.max_rows', 500)
cars['Location.2'].value_counts()
# Out:
# Quezon City                     2975
# Manila                          1892
# Quezon                          1813
# Makati                          1407
# Philippines                     1271
# Pasig                           1145
# Paranaque                        865
# Cebu City                        591
# Las Pinas                        590
# Marikina                         429
# Taguig                           301
# Muntinlupa                       300
# Mandaue                          263
# San Fernando                     257
# Cainta                           257
# Antipolo                         256
# Mandaluyong                      237
# Pasay                            210
# Santiago                         191
# Angeles                          183
# General Salipada K. Pendatun     168
# Caloocan                         166
# Bacoor                           161
# Davao City                       141
# Valenzuela                       139
# ...

# %% [markdown]
# After finding and counting the values we need to select the data and assign it to our `final_df` variables.

# %%
final_df = cars.loc[(cars["Location.2"]=="Cebu") | (cars["Location.2"]=="Cebu City") | (cars["Location.2"]=="Consolacion")
                  | (cars["Location.2"]=="Cordova") | (cars["Location.2"]=="Danao") | (cars["Location.2"]=="Dumanjug")
                  | (cars["Location.2"]=="Lapu-Lapu")| (cars["Location.2"]=="Liloan")| (cars["Location.2"]=="Mandaue")
                   | (cars["Location.2"]=="Naga")  | (cars["Location.2"]=="Talisay") ]

# %% [markdown]
# We also need to replace null values for the `Color Family` and `Fuel Type` variable.

# %%
#replaced null color values as 'No Color'. Same for the fuel type.
final_df['Color Family']=final_df['Color Family'].fillna('Other') #('No Color')
final_df['Fuel Type']=final_df['Fuel Type'].fillna('No Fuel Type')

# %% [markdown]
# Since there is no age variable in the dataset. We will add a new column called `age_of_car` that is derived from the year the car has been manufactured. We can also use this to fill the missing values in our `Mileage (in km)` variable.

# %%
final_df['age_of_car']=2021-final_df['Year of Manufacture']
final_df.head()
# Out:
#            ID                                Title   Price   Brand  \
# 5   CAR014565             1989 Toyota Crown 3.0 MT  195000  Toyota
# 6   CAR014569          1992 Mazda B2200 2.2 4x2 MT  250000   Mazda
# 18  CAR014654      2000 Ford Expedition 4.6 4x2 AT  250000    Ford
# 19  CAR014656  2000 Ford Expedition 4.6 XLT 4x2 AT  250000    Ford
# 23  CAR014683   2011 Toyota Corolla Altis 1.6 V AT  419000  Toyota
#
#             Model  Year of Manufacture Used Transmission   Color Family  \
# 5           Crown                 1989  Yes       Manual          White
# 6           B2200                 1992  Yes       Manual          White
# 18     Expedition                 2000  Yes    Automatic          White
# 19     Expedition                 2000  Yes    Automatic          White
# 23  Corolla Altis                 2011  Yes    Automatic  Silver / Grey
#
#     Mileage (in km)  ...                                        Description  \
# ...

# %% [markdown]
# **We will drop the other columns in our dataset, since they are categorical variables that cannot be categorized. Take note that we also created a new variable called `age_of_car` so there is no need to use the `Year of Manufacture` variable, thus we also need to drop it.

# %%
final_df.drop(columns=['Poster','Version','Description','Title','Used','name','Date Posted','Year of Manufacture'],inplace=True,axis=1)

# %%
# Checking our selected rows base on this values
final_df['Location.2'].value_counts()
# Out:
# Cebu City      591
# Mandaue        263
# Talisay         82
# Cebu            68
# Lapu-Lapu       45
# Naga            25
# Consolacion     11
# Liloan          11
# Cordova          3
# Danao            2
# Dumanjug         2
# Name: Location.2, dtype: int64

# %%
# Select only the rows with relevant values that is greater or equal to zero
final_df=final_df[final_df['age_of_car']>=0]
final_df=final_df[final_df['retail']>0]
final_df.head()
# Out:
#            ID   Price   Brand          Model Transmission   Color Family  \
# 6   CAR014569  250000   Mazda          B2200       Manual          White
# 18  CAR014654  250000    Ford     Expedition    Automatic          White
# 19  CAR014656  250000    Ford     Expedition    Automatic          White
# 23  CAR014683  419000  Toyota  Corolla Altis    Automatic  Silver / Grey
# 30  CAR014768  330000    Ford         Fiesta    Automatic           Blue
#
#     Mileage (in km)       Body Type Poster Type Fuel Type Location.2   retail  \
# 6               1.0  Pickup / Truck      Dealer    Diesel    Mandaue   991800
# 18              1.0             SUV      Dealer  Gasoline    Mandaue  4258000
# 19              1.0             SUV      Dealer  Gasoline    Mandaue  4258000
# 23              1.0  Saloon / Sedan      Dealer  Gasoline       Cebu  1131000
# 30              1.0  Saloon / Sedan      Dealer  Gasoline    Mandaue   875000
#
#     Post Age  age_of_car
# 6         62          29
# ...

# %% [markdown]
# ## Imputing the Mileage Variable using K-Nearest Neigbors Algorithm
# ***
# According to its variable definition, Mileage is the total number of miles that the vehicle have travelled at the time it was purchased. Since the Mileage of the car is one of the most important thing to consider when buying used cars, We will be using the ``age_of_car`` variable to get the mean of the k outputs and impute the null values in the ``Mileage (in km)`` variable using kNN.

# %%
#gets the age of car with no null values in the mileage
X=pd.DataFrame(final_df['age_of_car'].loc[final_df['Mileage (in km)'].notnull()])
#gets the age of car with null values in the mileage
X_null=pd.DataFrame(final_df['age_of_car'].loc[final_df['Mileage (in km)'].isnull()])
#gets the mileage with no null values in the mileage
y=pd.DataFrame(final_df['Mileage (in km)'].loc[final_df['Mileage (in km)'].notnull()])
#gets the mileage with null values in the mileage
y_null=pd.DataFrame(final_df['Mileage (in km)'].loc[final_df['Mileage (in km)'].isnull()])

# %%
# The K is according to the study that is based from our dataset
clf=KNeighborsRegressor(10,weights='distance')
trained_model=clf.fit(X,y)

# %%
#predicting imputed values and setting the index to match the X_null dataframe
imputed_val=pd.DataFrame(trained_model.predict(X_null),columns=['Mileage (in km)'])
X_null.reset_index(inplace=True)

# %%
# kNN accuracy is 
from math import sqrt
print(trained_model.score(X,y))
# Out:
# 0.6886807196625311

# %% [markdown]
# **kNN's accuracy is 69%

# %%
# What is k?
from sklearn.metrics import mean_squared_error, r2_score
import random
from sklearn.model_selection import train_test_split
# splitting train 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
error = []
for k in range(1,51):
    clf=KNeighborsRegressor(k)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    error.append(mean_squared_error(y_test,y_pred))

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,51),error)

# %% [markdown]
# **As you can see in the plot, Choosing 10 as K reduces the mean squared error in our dataset

# %%
#merge imputed values with your age_of_car pair
null_merged=pd.merge(X_null,imputed_val,how='outer',on=X_null.index)
#deleted useless key column that came from  the mileage dataframe
null_merged.drop('key_0',inplace=True,axis=1)
#index of age_of_car is set as the index
null_merged.set_index('index',inplace=True)

# %%
# merged them all together (age_of_car and Mileage) non null records
xy_merged=pd.concat([X,y],axis=1)
# merged the non nulls with the imputed or previous nulls
merged_df=pd.concat([null_merged,xy_merged],axis=0)
# rearranged indedx so it's prettier
merged_df=merged_df.sort_index()
merged_df.head()
# Out:
#     age_of_car  Mileage (in km)
# 6           29              1.0
# 18          21              1.0
# 19          21              1.0
# 23          10              1.0
# 30           9              1.0

# %%
# merge it with the whole df but original null mileage and age is still there
total_merge=pd.merge(final_df,merged_df,on=final_df.index)
# dropped the original null mileage and age. The new boys are in town!
total_merge.drop(['age_of_car_x','Mileage (in km)_x','key_0'],axis=1,inplace=True)
#renamed them
total_merge.columns=['id','price','brand','model','transmission','color','body_type','poster_type','fuel_type','location','retail','post_age_in_days','age_of_car','mileage_in_km']
total_merge.head()
# Out:
#           id   price   brand          model transmission          color  \
# 0  CAR014569  250000   Mazda          B2200       Manual          White
# 1  CAR014654  250000    Ford     Expedition    Automatic          White
# 2  CAR014656  250000    Ford     Expedition    Automatic          White
# 3  CAR014683  419000  Toyota  Corolla Altis    Automatic  Silver / Grey
# 4  CAR014768  330000    Ford         Fiesta    Automatic           Blue
#
#         body_type poster_type fuel_type location   retail  post_age_in_days  \
# 0  Pickup / Truck      Dealer    Diesel  Mandaue   991800                62
# 1             SUV      Dealer  Gasoline  Mandaue  4258000                62
# 2             SUV      Dealer  Gasoline  Mandaue  4258000                62
# 3  Saloon / Sedan      Dealer  Gasoline     Cebu  1131000                45
# 4  Saloon / Sedan      Dealer  Gasoline  Mandaue   875000                62
#
#    age_of_car  mileage_in_km
# 0          29            1.0
# ...

# %%
#made the dataframe prettier by moving the id as index and deleting that pesky id title
total_merge.set_index('id',inplace=True)
total_merge.rename_axis(index=None,inplace=True)
total_merge.head()
# Out:
#             price   brand          model transmission          color  \
# CAR014569  250000   Mazda          B2200       Manual          White
# CAR014654  250000    Ford     Expedition    Automatic          White
# CAR014656  250000    Ford     Expedition    Automatic          White
# CAR014683  419000  Toyota  Corolla Altis    Automatic  Silver / Grey
# CAR014768  330000    Ford         Fiesta    Automatic           Blue
#
#                 body_type poster_type fuel_type location   retail  \
# CAR014569  Pickup / Truck      Dealer    Diesel  Mandaue   991800
# CAR014654             SUV      Dealer  Gasoline  Mandaue  4258000
# CAR014656             SUV      Dealer  Gasoline  Mandaue  4258000
# CAR014683  Saloon / Sedan      Dealer  Gasoline     Cebu  1131000
# CAR014768  Saloon / Sedan      Dealer  Gasoline  Mandaue   875000
#
#            post_age_in_days  age_of_car  mileage_in_km
# CAR014569                62          29            1.0
# ...

# %% [markdown]
# # Describing Numerical Features
# ***
# Before we get to an in-depth exploration of the data or even building the model, we should explore the data a little more and see how the data is distributed and if there are any outliers. We will add a few more metrics to the summary data frame, that it now includes a metric for three standard deviations below and above the mean.

# %%
desc_df = total_merge.describe()
# add the standard deviation metric
desc_df.loc['+3_std'] = desc_df.loc['mean'] + (desc_df.loc['std'] * 3)
desc_df.loc['-3_std'] = desc_df.loc['mean'] - (desc_df.loc['std'] * 3)

# display it
desc_df
# Out:
#                price        retail  post_age_in_days   age_of_car  \
# count   1.014000e+03  1.014000e+03       1014.000000  1014.000000
# mean    8.220067e+05  1.342499e+06         57.582840     7.758383
# std     6.813220e+05  7.911477e+05         41.522227     5.698392
# min     7.000000e+04  2.100000e+05          9.000000     2.000000
# 25%     3.900000e+05  8.290000e+05         30.000000     4.000000
# 50%     6.290000e+05  1.158000e+06         43.000000     7.000000
# 75%     1.006750e+06  1.607000e+06         76.000000    10.000000
# max     5.950000e+06  8.920000e+06        744.000000    47.000000
# +3_std  2.865973e+06  3.715942e+06        182.149520    24.853559
# -3_std -1.221959e+06 -1.030944e+06        -66.983840    -9.336794
#
#         mileage_in_km
# count    1.014000e+03
# mean     4.793736e+04
# std      1.271408e+05
# min      1.000000e+00
# 25%      5.628000e+03
# 50%      3.500000e+04
# 75%      6.473320e+04
# max      3.000000e+06
# +3_std   4.293598e+05
# ...

# %% [markdown]
# **We see that there are some values that exceed 3 standard deviations, such enormous value would qualify as an outlier

# %% [markdown]
# ## Removing the dataset's outlier using Z-Score
# ***
# The Z-score is the number of standard deviations from the mean a data point is, so if it's less than 3 we keep it otherwise we drop it.

# %%
# filter the data frame to remove the values exceeding 3 standard deviations
removed_df = total_merge[(np.abs(stats.zscore(total_merge[['price', 'retail', 'post_age_in_days', 'age_of_car']])) < 3).all(axis=1)]

# what rows were removed
total_merge.index.difference(removed_df.index)
# Out:
# Index(['CAR001337', 'CAR001856', 'CAR002575', 'CAR002643', 'CAR003595',
#        'CAR003804', 'CAR006111', 'CAR006397', 'CAR009236', 'CAR009818',
#        'CAR010063', 'CAR010064', 'CAR010168', 'CAR010900', 'CAR011165',
#        'CAR011840', 'CAR011861', 'CAR012787', 'CAR012841', 'CAR013256',
#        'CAR013550', 'CAR013667', 'CAR013881', 'CAR013882', 'CAR013883',
#        'CAR013884', 'CAR013885', 'CAR013886', 'CAR013887', 'CAR013888',
#        'CAR013937', 'CAR013948', 'CAR013977', 'CAR014015', 'CAR014016',
#        'CAR014030', 'CAR014031', 'CAR014291', 'CAR014292', 'CAR014327',
#        'CAR014361', 'CAR014435', 'CAR014569', 'CAR014573', 'CAR014595',
#        'CAR014654', 'CAR014656', 'CAR014678', 'CAR015057', 'CAR015572',
#        'CAR015619', 'CAR015796', 'CAR015975', 'CAR016052', 'CAR016180',
#        'CAR016503', 'CAR016604', 'CAR016720', 'CAR016737', 'CAR017379',
#        'CAR017380', 'CAR017381', 'CAR017409', 'CAR017561', 'CAR017608',
# ...

# %%
total_merge = total_merge[total_merge.isin(total_merge)].dropna()
total_merge
# Out:
#             price    brand          model transmission          color  \
# CAR014569  250000    Mazda          B2200       Manual          White
# CAR014654  250000     Ford     Expedition    Automatic          White
# CAR014656  250000     Ford     Expedition    Automatic          White
# CAR014683  419000   Toyota  Corolla Altis    Automatic  Silver / Grey
# CAR014768  330000     Ford         Fiesta    Automatic           Blue
# ...           ...      ...            ...          ...            ...
# CAR018809  720000   Toyota           Vios    Automatic          Green
# CAR019467  390000   Nissan       Frontier       Manual            Red
# CAR019701  380000    Honda           City    Automatic  Silver / Grey
# CAR019713  780000  Hyundai   Grand Starex    Automatic          Black
# CAR019859  485000    Isuzu      Crosswind    Automatic  Silver / Grey
#
#                          body_type poster_type fuel_type location   retail  \
# ...

# %% [markdown]
# ## Scatterplot
# ***

# %%
# Scatter plot for numerical features
num_features = ['price', 'retail', 'post_age_in_days', 'age_of_car']
sns.pairplot(total_merge[num_features], size = 2.5)
plt.show();

# %% [markdown]
# ## Histogram
# ***

# %%
total_merge['location'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As you can see in the histogram, most car sold online comes from cebu city

# %%
total_merge['brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Most sold used cars comes from the brand Toyota

# %% [markdown]
# ## Correlation Matrix
# ***

# %%
# General correlation matrix
num_features = ['price', 'retail', 'post_age_in_days', 'age_of_car']
corrmat = total_merge[num_features].corr()
corrmat
# Out:
#                      price    retail  post_age_in_days  age_of_car
# price             1.000000  0.544751          0.193121   -0.456756
# retail            0.544751  1.000000          0.018326    0.187004
# post_age_in_days  0.193121  0.018326          1.000000   -0.172735
# age_of_car       -0.456756  0.187004         -0.172735    1.000000

# %% [markdown]
# **We will remove the ``post_age_in_days`` variable because it has a very strong correlation with our dependent variable.

# %%
total_merge.drop("post_age_in_days", axis=1, inplace=True)
total_merge.head()
# Out:
#             price   brand          model transmission          color  \
# CAR014569  250000   Mazda          B2200       Manual          White
# CAR014654  250000    Ford     Expedition    Automatic          White
# CAR014656  250000    Ford     Expedition    Automatic          White
# CAR014683  419000  Toyota  Corolla Altis    Automatic  Silver / Grey
# CAR014768  330000    Ford         Fiesta    Automatic           Blue
#
#                 body_type poster_type fuel_type location   retail  age_of_car  \
# CAR014569  Pickup / Truck      Dealer    Diesel  Mandaue   991800          29
# CAR014654             SUV      Dealer  Gasoline  Mandaue  4258000          21
# CAR014656             SUV      Dealer  Gasoline  Mandaue  4258000          21
# CAR014683  Saloon / Sedan      Dealer  Gasoline     Cebu  1131000          10
# CAR014768  Saloon / Sedan      Dealer  Gasoline  Mandaue   875000           9
#
#            mileage_in_km
# CAR014569            1.0
# CAR014654            1.0
# ...

# %% [markdown]
# # Merging Similar Categorical Values

# %% [markdown]
# For example, 'Bmw' and 'BMW' are the same values, just in different letter case or format. In this case, we replace 'Bmw' values with 'BMW' in order to only have one unique BMW model value when we get the dummy columns later on.

# %%
# checks the total count
total_merge['brand'].value_counts()
# Out:
# Toyota           372
# Nissan            93
# Honda             93
# Mitsubishi        86
# Hyundai           84
# Ford              77
# Kia               67
# Isuzu             53
# Suzuki            32
# Subaru            17
# Chevrolet         17
# Mazda             12
# BMW                5
# Jeep               2
# Hummer             1
# Bmw                1
# Mercedes-Benz      1
# Lexus              1
# Name: brand, dtype: int64

# %%
# merge the similar values 
total_merge['brand'] = total_merge['brand'].replace(['Bmw'],'BMW')

# %%
# checks the total count
total_merge['brand'].value_counts()
# Out:
# Toyota           372
# Nissan            93
# Honda             93
# Mitsubishi        86
# Hyundai           84
# Ford              77
# Kia               67
# Isuzu             53
# Suzuki            32
# Subaru            17
# Chevrolet         17
# Mazda             12
# BMW                6
# Jeep               2
# Hummer             1
# Mercedes-Benz      1
# Lexus              1
# Name: brand, dtype: int64

# %%
# checks the total count
total_merge['model'].value_counts()
# Out:
# Fortuner              61
# Vios                  55
# Innova                46
# Wigo                  34
# Hilux                 31
# City                  30
# Everest               25
# MonteroSport          24
# Cr-V                  23
# Navara                21
# Crosswind             20
# Sportage              20
# Civic                 19
# Rio                   19
# Hiace                 18
# Almera                17
# GrandStarex           17
# Nv350Urvan            16
# Camry                 16
# D-Max                 16
# Sorento               15
# Corolla               14
# Eon                   14
# CorollaAltis          13
# Accent                13
# Strada                13
# Rav4                  13
# Pajero                12
# LandCruiserPrado      12
# Avanza                12
# Forester              12
# Ecosport              12
# Picanto               11
# LandCruiser           11
# Ranger                11
# Celerio               11
# X-Trail               11
# ...

# %%
# merge similar values into model variable
total_merge['model'] = total_merge['model'].replace(['CorollaAltis'],'Corolla Altis')
total_merge['model'] = total_merge['model'].replace(['Cr-V'],'CR-V')
total_merge['model'] = total_merge['model'].replace(['Ecosport'],'EcoSport')
total_merge['model'] = total_merge['model'].replace(['FjCruiser'],'FJ Cruiser')
total_merge['model'] = total_merge['model'].replace(['GrandStarex'],'Grand Starex')
total_merge['model'] = total_merge['model'].replace(['H100'],'H-100')
total_merge['model'] = total_merge['model'].replace(['Hr-V'],'HR-V')
total_merge['model'] = total_merge['model'].replace(['LandCruiserPrado'],'Land Cruiser Prado')
total_merge['model'] = total_merge['model'].replace(['MirageG4'],'Mirage G4')
total_merge['model'] = total_merge['model'].replace(['Nv350Urvan'],'NV350 Urvan')
total_merge['model'] = total_merge['model'].replace(['Rav4'],'RAV4')

# %%
# checks the total count
total_merge['model'].value_counts()
# Out:
# Fortuner              61
# Vios                  55
# Innova                46
# Wigo                  34
# Hilux                 31
# City                  30
# CR-V                  27
# Everest               25
# MonteroSport          24
# Navara                21
# Crosswind             20
# Sportage              20
# Civic                 19
# Rio                   19
# NV350 Urvan           18
# Hiace                 18
# Corolla Altis         18
# Grand Starex          18
# Almera                17
# D-Max                 16
# Camry                 16
# RAV4                  16
# Sorento               15
# EcoSport              14
# Eon                   14
# Corolla               14
# Strada                13
# Land Cruiser Prado    13
# Accent                13
# Pajero                12
# Forester              12
# Avanza                12
# X-Trail               11
# Picanto               11
# Ranger                11
# Celerio               11
# LandCruiser           11
# ...

# %%
# checks the total count
total_merge['transmission'].value_counts()
# Out:
# Automatic     632
# Manual        380
# Automanual      1
# Cvt             1
# Name: transmission, dtype: int64

# %%
# checks the total count
total_merge['color'].value_counts()
# Out:
# White            242
# Black            196
# Silver           128
# Red              119
# Blue              77
# Grey              69
# Brown             33
# Silver / Grey     32
# Beige             32
# Orange            25
# Other             21
# Yellow             8
# Pearlwhite         8
# Green              7
# Grayblack          7
# Pink               3
# Gold               2
# Purple             2
# Skyblue            1
# Brightsilver       1
# Golden             1
# Name: color, dtype: int64

# %%
# merge similar values into color variables
total_merge['color'] = total_merge['color'].replace(['Silver'],'Silver / Grey')
total_merge['color'] = total_merge['color'].replace(['Grey'],'Silver / Grey')
total_merge['color'] = total_merge['color'].replace(['Pearlwhite'],'White')
total_merge['color'] = total_merge['color'].replace(['Brightsilver'],'Silver / Grey')
total_merge['color'] = total_merge['color'].replace(['Skyblue'],'Blue')
total_merge['color'] = total_merge['color'].replace(['Golden'],'Gold')

# %%
# checks the total count
total_merge['color'].value_counts()
# Out:
# White            250
# Silver / Grey    230
# Black            196
# Red              119
# Blue              78
# Brown             33
# Beige             32
# Orange            25
# Other             21
# Yellow             8
# Green              7
# Grayblack          7
# Gold               3
# Pink               3
# Purple             2
# Name: color, dtype: int64

# %%
# checks the total count
total_merge['body_type'].value_counts()
# Out:
# SUV                                   340
# Saloon / Sedan                        257
# MPV / AUV                             105
# Pickup / Truck                        103
# Hatchback / Wagon                     101
# Van / Minivan / Minibus                92
# Coupe / Sports Car                     15
# Cabriolet / Convertible / Roadster      1
# Name: body_type, dtype: int64

# %%
# checks the total count
total_merge['poster_type'].value_counts()
# Out:
# Dealer        595
# Individual    419
# Name: poster_type, dtype: int64

# %%
# checks the total count
total_merge['fuel_type'].value_counts()
# Out:
# Gasoline        371
# No Fuel Type    346
# Diesel          297
# Name: fuel_type, dtype: int64

# %%
# checks the total count
total_merge['location'].value_counts()
# Out:
# Cebu City      545
# Mandaue        247
# Talisay         77
# Cebu            65
# Lapu-Lapu       35
# Naga            23
# Consolacion     10
# Liloan           7
# Danao            2
# Dumanjug         2
# Cordova          1
# Name: location, dtype: int64

# %% [markdown]
# ### Using dummy variables to represent the Categorical Variables
# ***
# We need to use the pandas function ``get_dummies`` to represent our categorical variables.

# %%
# encoding the dummy values
brand = pd.get_dummies(total_merge["brand"], drop_first=True, prefix="brand")
model = pd.get_dummies(total_merge["model"], drop_first=True, prefix="model")
transmission = pd.get_dummies(total_merge["transmission"], drop_first=True, prefix="transmission")
color = pd.get_dummies(total_merge["color"], drop_first=True, prefix="color")
body_type = pd.get_dummies(total_merge["body_type"], drop_first=True, prefix="body_type")
poster_type = pd.get_dummies(total_merge["poster_type"], drop_first=True, prefix="poster_type")
fuel_type = pd.get_dummies(total_merge["fuel_type"], drop_first=True, prefix="fuel_type")
location = pd.get_dummies(total_merge["location"], drop_first=True, prefix="location")

# %%
# dropping the old dummy columns
total_merge.drop("brand", axis=1, inplace=True)
total_merge.drop("model", axis=1, inplace=True)
total_merge.drop("transmission", axis=1, inplace=True)
total_merge.drop("color", axis=1, inplace=True)
total_merge.drop("body_type", axis=1, inplace=True)
total_merge.drop("fuel_type", axis=1, inplace=True)
total_merge.drop("location", axis=1, inplace=True)
total_merge.drop("poster_type", axis=1, inplace=True)
total_merge.head()
# Out:
#             price   retail  age_of_car  mileage_in_km
# CAR014569  250000   991800          29            1.0
# CAR014654  250000  4258000          21            1.0
# CAR014656  250000  4258000          21            1.0
# CAR014683  419000  1131000          10            1.0
# CAR014768  330000   875000           9            1.0

# %%
# merging the newly created dummy variables with our final dataframe
total_merge = pd.concat([total_merge, brand, model, transmission, color, body_type, poster_type, fuel_type, location], axis=1)
total_merge.head()
# Out:
#             price   retail  age_of_car  mileage_in_km  brand_Chevrolet  \
# CAR014569  250000   991800          29            1.0                0
# CAR014654  250000  4258000          21            1.0                0
# CAR014656  250000  4258000          21            1.0                0
# CAR014683  419000  1131000          10            1.0                0
# CAR014768  330000   875000           9            1.0                0
#
#            brand_Ford  brand_Honda  brand_Hummer  brand_Hyundai  brand_Isuzu  \
# CAR014569           0            0             0              0            0
# CAR014654           1            0             0              0            0
# CAR014656           1            0             0              0            0
# CAR014683           0            0             0              0            0
# CAR014768           1            0             0              0            0
#
# ...

# %% [markdown]
# ### Testing the perfomance of our Model
# ***

# %%
# for our backup purpose
final_df=total_merge.copy()

# %%
from sklearn.model_selection import train_test_split
# splitting train and test data
X = final_df.drop("price", axis=1)
y = final_df["price"]
# splitting 80% train and 20% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn import linear_model
#Training model
lr_model=linear_model.LinearRegression()
lr_model
# Out:
# LinearRegression()

# %%
#Fit the trained model
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Accuracy of the model
lr=lr_model.score(X_train, y_train)
print('Accuracy of the Model :',lr)
# Out:
# Accuracy of the Model : 0.8675489619674193

# %% [markdown]
# ## Improving Model Performance
# ***
# To further improve the performance of our model, We will add a new binary indicator called ``isAffordable`` that will be 1 if the used car price is less than or equal to its retail price, zero otherwise.

# %%
total_merge["isAffordable"] = np.where(total_merge["price"] <= total_merge["retail"], 1, 0)
total_merge.head()
# Out:
#             price   retail  age_of_car  mileage_in_km  brand_Chevrolet  \
# CAR014569  250000   991800          29            1.0                0
# CAR014654  250000  4258000          21            1.0                0
# CAR014656  250000  4258000          21            1.0                0
# CAR014683  419000  1131000          10            1.0                0
# CAR014768  330000   875000           9            1.0                0
#
#            brand_Ford  brand_Honda  brand_Hummer  brand_Hyundai  brand_Isuzu  \
# CAR014569           0            0             0              0            0
# CAR014654           1            0             0              0            0
# CAR014656           1            0             0              0            0
# CAR014683           0            0             0              0            0
# CAR014768           1            0             0              0            0
#
#            ...  location_Consolacion  location_Cordova  location_Danao  \
# ...

# %%
import statsmodels.api as sm
final_df=total_merge.copy()
X = final_df.drop("price", axis=1)
y = final_df["price"]
X = sm.add_constant(X_train) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_train) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     38.96
# Date:                Wed, 24 Mar 2021   Prob (F-statistic):          1.44e-249
# Time:                        15:20:03   Log-Likelihood:                -11078.
# No. Observations:                 811   AIC:                         2.246e+04
# Df Residuals:                     661   BIC:                         2.316e+04
# Df Model:                         149
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **After we add the ``isAffordable`` variable, we can see the improvement of our r2 from 87% to 90%. ``isAffordable`` also is a significant variable since its p-value is less than 5%. p-values for categorical values are ommited since it is just a multiple dummy representation of one categorical variable in our dataset.

# %%
#  Model's Coefficient
from sklearn.linear_model import LinearRegression
model = LinearRegression()
# Fit linear model by passing test dataset
model = model.fit(X_train,y_train)
coeff_df = pd.DataFrame(model.coef_, X_test.columns,columns=['Coefficient'])
print(coeff_df)
# Out:
#                                     Coefficient
# retail                             4.028352e-01
# age_of_car                        -5.725066e+04
# mileage_in_km                     -1.862250e-01
# brand_Chevrolet                    2.105318e+05
# brand_Ford                         2.036207e+05
# brand_Honda                        3.285544e+05
# brand_Hummer                       2.985839e+05
# brand_Hyundai                      1.901285e+05
# brand_Isuzu                        1.655573e+05
# brand_Jeep                         2.401937e+05
# brand_Kia                          2.308304e+04
# brand_Lexus                       -2.553814e+04
# brand_Mazda                        2.798083e+05
# brand_Mercedes-Benz               -6.398704e+05
# brand_Mitsubishi                   2.096181e+05
# brand_Nissan                       1.777229e+05
# brand_Subaru                       2.149312e+05
# brand_Suzuki                       1.777592e+05
# brand_Toyota                       4.763236e+05
# ...

# %%
# Model's Intercept
model.intercept_
# Out:
# 942564.6299264448

# %% [markdown]
# ### Regression Equation
#
# After enhancing our model, We can now produce the regression equation from each slope of our variables. The price of used cars is predicted by:
#
# $$price = 942564.6299264448 +  (0.4028352 * retail)  - (57250.66 * age\_of\_car) - (0.186225 * mileage\_in\_km) - (12809.13 + poster\_type\_Individual) - (927499.2 * isAffordable) + brand + model + transmission + color + body\_type + fuel\_type + location $$

# %% [markdown]
# ## Conclusions and Recommendations
# ***
# Write here

# %% [markdown]
# Sources:
# - https://www.sunstar.com.ph/article/410513/More-than-half-a-million-cars-clog-Cebus-streets
# - https://www.kenresearch.com/blog/2020/03/philippines-used-car-market-analysis/
# - http://rsso07.psa.gov.ph/
# - https://github.com/nicolelumagui/FTW-Capstone_Second-Hand-Cars-in-PH
